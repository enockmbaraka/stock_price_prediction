# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the scaler
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow.lite as tflite
import random

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pickle

def preprocess_stock_data(
    csv_path, 
    date_column='Date', 
    close_column='Close', 
    test_size=0.2, 
    validation_size=0.1,
    time_steps=60, 
    scaler_output_file='outputs/google_scale.pkl'
):
    """
    Prepares stock market price data for time series modeling, with training, validation, and test splits.

    Args:
        csv_path (str): Path to the CSV file containing the data.
        date_column (str): Name of the date column in the CSV.
        close_column (str): Name of the closing price column in the CSV.
        test_size (float): Proportion of the data for testing.
        validation_size (float): Proportion of the data for validation.
        time_steps (int): Number of past time steps to use for each sample.
        scaler_output_file (str): Path to save the fitted MinMaxScaler instance.

    Returns:
        X_train (numpy.ndarray): Training data (features).
        y_train (numpy.ndarray): Training labels.
        X_val (numpy.ndarray): Validation data (features).
        y_val (numpy.ndarray): Validation labels.
        X_test (numpy.ndarray): Testing data (features).
        y_test (numpy.ndarray): Testing labels.
    """
    try:
        # Load the dataset
        if not os.path.exists(csv_path):
            raise FileNotFoundError(f"CSV file not found at path: {csv_path}")

        data = pd.read_csv(csv_path, parse_dates=[date_column])
        data.sort_values(by=date_column, inplace=True)

        print(f"CSV file successfully loaded. Columns: {data.columns}")
    except Exception as e:
        raise ValueError(f"Error reading CSV file or parsing date column '{date_column}': {e}")
    
    # Validate columns
    if date_column not in data.columns or close_column not in data.columns:
        raise ValueError(f"Columns '{date_column}' or '{close_column}' not found in dataset. Available columns: {data.columns}")

    try:
        # Extract the 'close' column for scaling
        close_prices = data[close_column].values.reshape(-1, 1)
    except Exception as e:
        raise ValueError(f"Error accessing '{close_column}' column: {e}")
    
    # Scale the data
    try:
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_close = scaler.fit_transform(close_prices)

        # Save the scaler to a file
        with open(scaler_output_file, 'wb') as f:
            pickle.dump(scaler, f)
        print(f"Scaler saved to {scaler_output_file}")
    except Exception as e:
        raise IOError(f"Error during scaling or saving scaler: {e}")
    
    # Create sequences of time_steps
    X, y = [], []
    try:
        for i in range(time_steps, len(scaled_close)):
            X.append(scaled_close[i - time_steps:i])
            y.append(scaled_close[i])
    except Exception as e:
        raise ValueError(f"Error creating sequences of time_steps: {e}")
    
    X, y = np.array(X), np.array(y)
    
    # Split data into train, validation, and test sets
    try:
        total_size = len(X)
        test_size_count = int(test_size * total_size)
        validation_size_count = int(validation_size * total_size)

        train_end_idx = total_size - test_size_count - validation_size_count
        val_end_idx = total_size - test_size_count

        X_train, X_val, X_test = X[:train_end_idx], X[train_end_idx:val_end_idx], X[val_end_idx:]
        y_train, y_val, y_test = y[:train_end_idx], y[train_end_idx:val_end_idx], y[val_end_idx:]

        # Adjust splits to match desired sample sizes
        train_samples = 554
        val_samples = 55
        test_samples = 84

        X_train, y_train = X[:train_samples], y[:train_samples]
        X_val, y_val = X[train_samples:train_samples + val_samples], y[train_samples:train_samples + val_samples]
        X_test, y_test = X[train_samples + val_samples:train_samples + val_samples + test_samples], y[train_samples + val_samples:train_samples + val_samples + test_samples]
    except Exception as e:
        raise ValueError(f"Error splitting data into train, validation, and test sets: {e}")
    
    print(f"Data split: {len(X_train)} training samples, {len(X_val)} validation samples, {len(X_test)} testing samples")
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
data = "inputs/google_stock_cleaned.csv"


try:
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_stock_data(
        data, 
        date_column='Date', 
        close_column='Close', 
        test_size=0.2, 
        time_steps=60, 
        scaler_output_file='outputs/google_scale.pkl'
    )

    # Outputs
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_train shape: {X_val.shape}, y_train shape: {y_val.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"Unexpected Error: {e}")
# Out:
# CSV file successfully loaded. Columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'daily_return', '20_day_ma', '50_day_ma'],
#       dtype='object')
# Scaler saved to outputs/google_scale.pkl
# Data split: 554 training samples, 55 validation samples, 84 testing samples
# X_train shape: (554, 60, 1), y_train shape: (554, 1)
# X_train shape: (55, 60, 1), y_train shape: (55, 1)
# X_test shape: (84, 60, 1), y_test shape: (84, 1)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (554, 60, 1)
# y_train shape: (554, 1)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import joblib
import numpy as np
import os

@tf.keras.utils.register_keras_serializable(package="Custom", name="symmetric_mean_absolute_percentage_error")
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    """
    Computes Symmetric Mean Absolute Percentage Error (SMAPE).

    Args:
        y_true: Ground truth values.
        y_pred: Predicted values.

    Returns:
        SMAPE as a TensorFlow tensor.
    """
    numerator = tf.abs(y_true - y_pred)
    denominator = (tf.abs(y_true) + tf.abs(y_pred)) / 2
    smape = tf.reduce_mean(numerator / denominator) * 100
    return smape


class StockPricePredictor_Google:
    def __init__(self, input_shape, learning_rate=0.0007971184552975506, num_layers=2, units=256):
        self.input_shape = input_shape  # Should be (time_steps, features)
        self.learning_rate = learning_rate
        self.num_layers = num_layers
        self.units = units
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        for i in range(self.num_layers):
            # Add RNN layers
            return_sequences = i < (self.num_layers - 1)
            model.add(SimpleRNN(self.units, activation='relu', return_sequences=return_sequences, input_shape=self.input_shape))
            model.add(Dropout(0.2))  # Regularization

        # Output layer for regression (single output: close value)
        model.add(Dense(1))

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[
                tf.keras.metrics.MeanAbsoluteError(),
                tf.keras.metrics.MeanAbsolutePercentageError(),
                symmetric_mean_absolute_percentage_error  # Custom SMAPE metric
            ]
        )
        return model

    def train(self, X_train, y_train, batch_size=16, epochs=50, validation_data=None, patience=15):
        """
        Trains the model with an EarlyStopping callback.
        
        Args:
            X_train: Training input data.
            y_train: Training target data.
            batch_size: Batch size for training.
            epochs: Maximum number of training epochs.
            validation_data: Tuple (X_val, y_val) for validation.
            patience: Number of epochs with no improvement after which training will be stopped.
        
        Returns:
            History object containing training details.
        """
        X_train = self._validate_and_reshape(X_train, expected_shape=(None, *self.input_shape))
        if validation_data:
            X_val = self._validate_and_reshape(validation_data[0], expected_shape=(None, *self.input_shape))
            validation_data = (X_val, validation_data[1])

        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True
        )

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=validation_data,
            callbacks=[early_stopping],
            verbose=2
        )
        return history

    def predict(self, X):
        X = self._validate_and_reshape(X, expected_shape=(None, *self.input_shape))
        return self.model.predict(X)

    def save(self, model_path):
        self.model.save(model_path)
        print(f"Model saved to {model_path}")

    @staticmethod
    def load(model_path, scaler_path):
        model = load_model(model_path, custom_objects={
            "symmetric_mean_absolute_percentage_error": symmetric_mean_absolute_percentage_error
        })
        print(f"Model loaded from {model_path}")

        scaler = joblib.load(scaler_path)
        print(f"Scaler loaded from {scaler_path}")

        return model, scaler

    def _validate_and_reshape(self, X, expected_shape):
        if len(X.shape) == 2:
            reshaped = X[..., np.newaxis]
            print(f"Reshaped input from {X.shape} to {reshaped.shape}")
            return reshaped
        elif len(X.shape) == len(expected_shape):
            print(f"Input shape is valid: {X.shape}")
            return X
        else:
            raise ValueError(f"Invalid input shape {X.shape}. Expected shape {expected_shape}.")

# %%
data_path_google = "inputs/google_stock_cleaned.csv"

#output_file = "scaled_stock_data_close_option.pkl"

# %%
if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_Google(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Prediction
    predictions = predictor.predict(X_test)

    
    model_path = "outputs/stock_price_rnn_google_model.keras"
    scaler_path = "outputs/google_scale.pkl"
    
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_Google.load(model_path, scaler_path)
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions)

    print("Predictions (rescaled):", predictions_rescaled)
# Out:
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# Epoch 1/50
# D:\stock_price_prediction\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 - 5s - 129ms/step - loss: 0.0114 - mean_absolute_error: 0.0698 - mean_absolute_percentage_error: 194135.9375 - symmetric_mean_absolute_percentage_error: 26.9603 - val_loss: 0.0045 - val_mean_absolute_error: 0.0614 - val_mean_absolute_percentage_error: 7.4817 - val_symmetric_mean_absolute_percentage_error: 7.9730
# Epoch 2/50
# 35/35 - 1s - 36ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - mean_absolute_percentage_error: 77420.7734 - symmetric_mean_absolute_percentage_error: 14.2935 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314 - val_mean_absolute_percentage_error: 3.8060 - val_symmetric_mean_absolute_percentage_error: 4.0460
# Epoch 3/50
# 35/35 - 1s - 35ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - mean_absolute_percentage_error: 112761.5078 - symmetric_mean_absolute_percentage_error: 12.4889 - val_loss: 0.0010 - val_mean_absolute_error: 0.0238 - val_mean_absolute_percentage_error: 2.8989 - val_symmetric_mean_absolute_percentage_error: 3.0709
# Epoch 4/50
# 35/35 - 1s - 34ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - mean_absolute_percentage_error: 92841.0938 - symmetric_mean_absolute_percentage_error: 12.3062 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266 - val_mean_absolute_percentage_error: 3.2342 - val_symmetric_mean_absolute_percentage_error: 3.4134
# Epoch 5/50
# 35/35 - 1s - 35ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - mean_absolute_percentage_error: 92744.4375 - symmetric_mean_absolute_percentage_error: 11.5380 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269 - val_mean_absolute_percentage_error: 3.2761 - val_symmetric_mean_absolute_percentage_error: 3.4362
# Epoch 6/50
# 35/35 - 1s - 35ms/step - loss: 0.0016 - mean_absolute_error: 0.0308 - mean_absolute_percentage_error: 107585.4375 - symmetric_mean_absolute_percentage_error: 11.6675 - val_loss: 7.5631e-04 - val_mean_absolute_error: 0.0188 - val_mean_absolute_percentage_error: 2.3663 - val_symmetric_mean_absolute_percentage_error: 2.2777
# Epoch 7/50
# 35/35 - 1s - 34ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - mean_absolute_percentage_error: 83414.7109 - symmetric_mean_absolute_percentage_error: 11.2897 - val_loss: 0.0047 - val_mean_absolute_error: 0.0636 - val_mean_absolute_percentage_error: 7.7512 - val_symmetric_mean_absolute_percentage_error: 8.2327
# Epoch 8/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - mean_absolute_percentage_error: 86714.3203 - symmetric_mean_absolute_percentage_error: 11.7962 - val_loss: 0.0020 - val_mean_absolute_error: 0.0372 - val_mean_absolute_percentage_error: 4.5127 - val_symmetric_mean_absolute_percentage_error: 4.7785
# Epoch 9/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - mean_absolute_percentage_error: 97700.1719 - symmetric_mean_absolute_percentage_error: 11.4965 - val_loss: 0.0029 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 5.7026 - val_symmetric_mean_absolute_percentage_error: 6.0571
# Epoch 10/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - mean_absolute_percentage_error: 83034.3516 - symmetric_mean_absolute_percentage_error: 11.4649 - val_loss: 6.7723e-04 - val_mean_absolute_error: 0.0166 - val_mean_absolute_percentage_error: 2.0882 - val_symmetric_mean_absolute_percentage_error: 2.0581
# Epoch 11/50
# 35/35 - 1s - 35ms/step - loss: 0.0019 - mean_absolute_error: 0.0329 - mean_absolute_percentage_error: 85935.4531 - symmetric_mean_absolute_percentage_error: 12.0745 - val_loss: 7.3664e-04 - val_mean_absolute_error: 0.0183 - val_mean_absolute_percentage_error: 2.3031 - val_symmetric_mean_absolute_percentage_error: 2.2291
# Epoch 12/50
# 35/35 - 1s - 34ms/step - loss: 0.0015 - mean_absolute_error: 0.0300 - mean_absolute_percentage_error: 80173.8125 - symmetric_mean_absolute_percentage_error: 11.1462 - val_loss: 0.0029 - val_mean_absolute_error: 0.0478 - val_mean_absolute_percentage_error: 5.8226 - val_symmetric_mean_absolute_percentage_error: 6.1508
# Epoch 13/50
# 35/35 - 1s - 35ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - mean_absolute_percentage_error: 102097.2891 - symmetric_mean_absolute_percentage_error: 11.8215 - val_loss: 0.0028 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 5.5820 - val_symmetric_mean_absolute_percentage_error: 5.9230
# Epoch 14/50
# 35/35 - 1s - 34ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - mean_absolute_percentage_error: 68852.8281 - symmetric_mean_absolute_percentage_error: 10.7707 - val_loss: 7.1669e-04 - val_mean_absolute_error: 0.0184 - val_mean_absolute_percentage_error: 2.2761 - val_symmetric_mean_absolute_percentage_error: 2.3223
# Epoch 15/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - mean_absolute_percentage_error: 82704.8906 - symmetric_mean_absolute_percentage_error: 10.7508 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249 - val_mean_absolute_percentage_error: 3.1247 - val_symmetric_mean_absolute_percentage_error: 2.9823
# Epoch 16/50
# 35/35 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - mean_absolute_percentage_error: 111125.3672 - symmetric_mean_absolute_percentage_error: 10.3806 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237 - val_mean_absolute_percentage_error: 2.8796 - val_symmetric_mean_absolute_percentage_error: 3.0260
# Epoch 17/50
# 35/35 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - mean_absolute_percentage_error: 85726.9141 - symmetric_mean_absolute_percentage_error: 11.1505 - val_loss: 6.7744e-04 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 2.0693 - val_symmetric_mean_absolute_percentage_error: 2.0487
# Epoch 18/50
# 35/35 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - mean_absolute_percentage_error: 83987.2891 - symmetric_mean_absolute_percentage_error: 10.5026 - val_loss: 6.9083e-04 - val_mean_absolute_error: 0.0172 - val_mean_absolute_percentage_error: 2.1362 - val_symmetric_mean_absolute_percentage_error: 2.1448
# Epoch 19/50
# 35/35 - 1s - 35ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - mean_absolute_percentage_error: 133324.7656 - symmetric_mean_absolute_percentage_error: 10.7515 - val_loss: 7.0350e-04 - val_mean_absolute_error: 0.0169 - val_mean_absolute_percentage_error: 2.1220 - val_symmetric_mean_absolute_percentage_error: 2.0895
# Epoch 20/50
# 35/35 - 1s - 34ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - mean_absolute_percentage_error: 99155.3516 - symmetric_mean_absolute_percentage_error: 10.0961 - val_loss: 8.2929e-04 - val_mean_absolute_error: 0.0202 - val_mean_absolute_percentage_error: 2.5330 - val_symmetric_mean_absolute_percentage_error: 2.4521
# Epoch 21/50
# 35/35 - 1s - 34ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - mean_absolute_percentage_error: 108702.6875 - symmetric_mean_absolute_percentage_error: 10.5507 - val_loss: 0.0013 - val_mean_absolute_error: 0.0295 - val_mean_absolute_percentage_error: 3.6857 - val_symmetric_mean_absolute_percentage_error: 3.5030
# Epoch 22/50
# 35/35 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0282 - mean_absolute_percentage_error: 101502.4062 - symmetric_mean_absolute_percentage_error: 10.9769 - val_loss: 7.5143e-04 - val_mean_absolute_error: 0.0180 - val_mean_absolute_percentage_error: 2.2552 - val_symmetric_mean_absolute_percentage_error: 2.2076
# Epoch 23/50
# 35/35 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - mean_absolute_percentage_error: 88096.3828 - symmetric_mean_absolute_percentage_error: 10.7405 - val_loss: 0.0028 - val_mean_absolute_error: 0.0456 - val_mean_absolute_percentage_error: 5.5404 - val_symmetric_mean_absolute_percentage_error: 5.8522
# Epoch 24/50
# 35/35 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - mean_absolute_percentage_error: 97647.1641 - symmetric_mean_absolute_percentage_error: 10.6644 - val_loss: 8.3156e-04 - val_mean_absolute_error: 0.0208 - val_mean_absolute_percentage_error: 2.5555 - val_symmetric_mean_absolute_percentage_error: 2.6365
# Epoch 25/50
# 35/35 - 1s - 35ms/step - loss: 0.0012 - mean_absolute_error: 0.0271 - mean_absolute_percentage_error: 94864.2266 - symmetric_mean_absolute_percentage_error: 10.2138 - val_loss: 8.0858e-04 - val_mean_absolute_error: 0.0194 - val_mean_absolute_percentage_error: 2.4468 - val_symmetric_mean_absolute_percentage_error: 2.3651
# Input shape is valid: (84, 60, 1)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step
# Model saved to outputs/stock_price_rnn_google_model.keras
# Model loaded from outputs/stock_price_rnn_google_model.keras
# Scaler loaded from outputs/google_scale.pkl
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Predictions (rescaled): [[183.69931]
#  [185.25615]
#  [186.3671 ]
#  [189.95306]
#  [190.16023]
#  [189.92432]
#  [191.24168]
#  [187.84709]
#  [186.08203]
#  [186.84381]
#  [185.41838]
#  [182.65836]
#  [179.57935]
#  [178.63644]
#  [181.32121]
#  [182.50273]
#  [176.14337]
#  [170.01022]
#  [168.05962]
#  [169.62694]
#  [170.87091]
#  [172.22235]
#  [172.00613]
#  [168.82198]
#  [162.41495]
#  [159.6894 ]
#  [159.59761]
#  [162.11862]
#  [164.2092 ]
#  [163.79565]
#  [164.72122]
#  [162.32346]
#  [162.05927]
#  [163.31555]
#  [166.59041]
#  [167.90396]
#  [167.25179]
#  [165.36531]
#  [166.08543]
#  [166.80719]
#  [165.98894]
#  [164.35396]
#  [163.13472]
#  [163.91583]
#  [159.98279]
#  [157.89355]
#  [157.99213]
#  [153.78728]
#  [150.56877]
#  [149.77655]
#  [151.57083]
#  [154.72221]
#  [157.794  ]
#  [158.96455]
#  [159.97997]
#  [160.58357]
#  [162.39247]
#  [164.01855]
#  [163.25854]
#  [163.17143]
#  [162.65631]
#  [163.36278]
#  [164.49486]
#  [166.28679]
#  [167.59596]
#  [167.12965]
#  [166.83339]
#  [167.62813]
#  [164.98166]
#  [165.01662]
#  [163.44907]
#  [163.09479]
#  [163.82129]
#  [165.49567]
#  [166.24966]
#  [166.22327]
#  [164.52354]
#  [164.27304]
#  [164.762  ]
#  [165.75755]
#  [164.35725]
#  [163.81621]
#  [165.52122]
#  [167.20938]]

# %%
if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_Google(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Save the model
    model_path = "outputs/stock_price_rnn_google_model.keras"
    scaler_path = "outputs/google_scale.pkl"
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_Google.load(model_path, scaler_path)

    # Predict on test data
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions).astype('float32')

    # Rescale test labels for evaluation (if scaled)
    y_test_rescaled = loaded_scaler.inverse_transform(y_test.reshape(-1, 1)).astype('float32')

    # Print predictions
    print("Predictions (rescaled):", predictions_rescaled.astype('float32'))

    # Evaluate metrics on test data
    metrics = loaded_model.evaluate(X_test, y_test, verbose=2)
    metric_names = loaded_model.metrics_names  # Get metric names for better interpretability

    # Display metrics
    for name, value in zip(metric_names, metrics):
        print(f"{name}: {value:.4f}")

    # Compute and display custom SMAPE manually for rescaled predictions
    smape_manual = symmetric_mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
    print(f"SMAPE (manual, rescaled): {smape_manual.numpy():.4f}")
# Out:
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# D:\stock_price_prediction\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 35/35 - 4s - 115ms/step - loss: 0.0118 - mean_absolute_error: 0.0700 - mean_absolute_percentage_error: 194081.8906 - symmetric_mean_absolute_percentage_error: 27.2866 - val_loss: 0.0029 - val_mean_absolute_error: 0.0467 - val_mean_absolute_percentage_error: 5.6501 - val_symmetric_mean_absolute_percentage_error: 6.0317
# Epoch 2/50
# 35/35 - 1s - 36ms/step - loss: 0.0023 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 101342.7344 - symmetric_mean_absolute_percentage_error: 13.8922 - val_loss: 0.0053 - val_mean_absolute_error: 0.0683 - val_mean_absolute_percentage_error: 8.3262 - val_symmetric_mean_absolute_percentage_error: 8.8636
# Epoch 3/50
# 35/35 - 1s - 36ms/step - loss: 0.0026 - mean_absolute_error: 0.0390 - mean_absolute_percentage_error: 97216.2500 - symmetric_mean_absolute_percentage_error: 13.7868 - val_loss: 0.0038 - val_mean_absolute_error: 0.0562 - val_mean_absolute_percentage_error: 6.8397 - val_symmetric_mean_absolute_percentage_error: 7.2547
# Epoch 4/50
# 35/35 - 1s - 35ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - mean_absolute_percentage_error: 97052.4844 - symmetric_mean_absolute_percentage_error: 12.3312 - val_loss: 7.6234e-04 - val_mean_absolute_error: 0.0191 - val_mean_absolute_percentage_error: 2.3992 - val_symmetric_mean_absolute_percentage_error: 2.3043
# Epoch 5/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - mean_absolute_percentage_error: 100023.0391 - symmetric_mean_absolute_percentage_error: 11.6291 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304 - val_mean_absolute_percentage_error: 3.7045 - val_symmetric_mean_absolute_percentage_error: 3.8828
# Epoch 6/50
# 35/35 - 1s - 36ms/step - loss: 0.0019 - mean_absolute_error: 0.0315 - mean_absolute_percentage_error: 122642.9766 - symmetric_mean_absolute_percentage_error: 11.7112 - val_loss: 6.8894e-04 - val_mean_absolute_error: 0.0177 - val_mean_absolute_percentage_error: 2.1841 - val_symmetric_mean_absolute_percentage_error: 2.2547
# Epoch 7/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - mean_absolute_percentage_error: 101378.5469 - symmetric_mean_absolute_percentage_error: 10.6777 - val_loss: 6.8780e-04 - val_mean_absolute_error: 0.0176 - val_mean_absolute_percentage_error: 2.1775 - val_symmetric_mean_absolute_percentage_error: 2.2295
# Epoch 8/50
# 35/35 - 1s - 36ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - mean_absolute_percentage_error: 118329.8047 - symmetric_mean_absolute_percentage_error: 11.5406 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286 - val_mean_absolute_percentage_error: 3.5802 - val_symmetric_mean_absolute_percentage_error: 3.3841
# Epoch 9/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - mean_absolute_percentage_error: 99715.8594 - symmetric_mean_absolute_percentage_error: 11.0810 - val_loss: 0.0019 - val_mean_absolute_error: 0.0359 - val_mean_absolute_percentage_error: 4.3533 - val_symmetric_mean_absolute_percentage_error: 4.5991
# Epoch 10/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - mean_absolute_percentage_error: 87186.2656 - symmetric_mean_absolute_percentage_error: 11.1134 - val_loss: 6.9332e-04 - val_mean_absolute_error: 0.0178 - val_mean_absolute_percentage_error: 2.2047 - val_symmetric_mean_absolute_percentage_error: 2.2337
# Epoch 11/50
# 35/35 - 1s - 35ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - mean_absolute_percentage_error: 99661.2734 - symmetric_mean_absolute_percentage_error: 11.2826 - val_loss: 7.5211e-04 - val_mean_absolute_error: 0.0193 - val_mean_absolute_percentage_error: 2.3792 - val_symmetric_mean_absolute_percentage_error: 2.4374
# Epoch 12/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - mean_absolute_percentage_error: 99595.0469 - symmetric_mean_absolute_percentage_error: 11.6429 - val_loss: 0.0017 - val_mean_absolute_error: 0.0355 - val_mean_absolute_percentage_error: 4.4339 - val_symmetric_mean_absolute_percentage_error: 4.1726
# Epoch 13/50
# 35/35 - 1s - 36ms/step - loss: 0.0015 - mean_absolute_error: 0.0301 - mean_absolute_percentage_error: 108962.5391 - symmetric_mean_absolute_percentage_error: 11.2456 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311 - val_mean_absolute_percentage_error: 3.7751 - val_symmetric_mean_absolute_percentage_error: 3.9713
# Epoch 14/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - mean_absolute_percentage_error: 98181.6641 - symmetric_mean_absolute_percentage_error: 11.0051 - val_loss: 9.0312e-04 - val_mean_absolute_error: 0.0218 - val_mean_absolute_percentage_error: 2.7409 - val_symmetric_mean_absolute_percentage_error: 2.6326
# Epoch 15/50
# 35/35 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - mean_absolute_percentage_error: 74090.0703 - symmetric_mean_absolute_percentage_error: 10.5472 - val_loss: 6.9869e-04 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 2.0735 - val_symmetric_mean_absolute_percentage_error: 2.0310
# Epoch 16/50
# 35/35 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - mean_absolute_percentage_error: 113527.3828 - symmetric_mean_absolute_percentage_error: 11.7798 - val_loss: 9.0362e-04 - val_mean_absolute_error: 0.0220 - val_mean_absolute_percentage_error: 2.6990 - val_symmetric_mean_absolute_percentage_error: 2.7860
# Epoch 17/50
# 35/35 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - mean_absolute_percentage_error: 73567.7266 - symmetric_mean_absolute_percentage_error: 10.7776 - val_loss: 7.7227e-04 - val_mean_absolute_error: 0.0197 - val_mean_absolute_percentage_error: 2.4234 - val_symmetric_mean_absolute_percentage_error: 2.4825
# Epoch 18/50
# 35/35 - 1s - 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - mean_absolute_percentage_error: 113056.8438 - symmetric_mean_absolute_percentage_error: 10.8230 - val_loss: 7.8505e-04 - val_mean_absolute_error: 0.0199 - val_mean_absolute_percentage_error: 2.4449 - val_symmetric_mean_absolute_percentage_error: 2.5029
# Epoch 19/50
# 35/35 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - mean_absolute_percentage_error: 76485.4453 - symmetric_mean_absolute_percentage_error: 10.6715 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255 - val_mean_absolute_percentage_error: 3.1120 - val_symmetric_mean_absolute_percentage_error: 3.2429
# Epoch 20/50
# 35/35 - 1s - 36ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - mean_absolute_percentage_error: 110596.1094 - symmetric_mean_absolute_percentage_error: 10.7073 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239 - val_mean_absolute_percentage_error: 2.9878 - val_symmetric_mean_absolute_percentage_error: 2.8695
# Epoch 21/50
# 35/35 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - mean_absolute_percentage_error: 94980.4688 - symmetric_mean_absolute_percentage_error: 10.7541 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269 - val_mean_absolute_percentage_error: 3.2785 - val_symmetric_mean_absolute_percentage_error: 3.4199
# Epoch 22/50
# 35/35 - 1s - 35ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - mean_absolute_percentage_error: 116683.3984 - symmetric_mean_absolute_percentage_error: 10.2606 - val_loss: 8.1964e-04 - val_mean_absolute_error: 0.0204 - val_mean_absolute_percentage_error: 2.5061 - val_symmetric_mean_absolute_percentage_error: 2.5777
# Model saved to outputs/stock_price_rnn_google_model.keras
# Model loaded from outputs/stock_price_rnn_google_model.keras
# Scaler loaded from outputs/google_scale.pkl
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FD0E70AE80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FD0E70AE80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# Predictions (rescaled): [[182.77179]
#  [184.14316]
#  [185.11885]
#  [188.44803]
#  [188.99333]
#  [188.81029]
#  [190.13286]
#  [187.23993]
#  [185.48026]
#  [185.99893]
#  [184.5826 ]
#  [182.1149 ]
#  [179.25217]
#  [178.02614]
#  [180.10815]
#  [181.2867 ]
#  [175.87125]
#  [170.1415 ]
#  [167.81204]
#  [168.63371]
#  [169.79366]
#  [171.15009]
#  [171.05356]
#  [168.22844]
#  [162.34105]
#  [159.49228]
#  [158.95808]
#  [160.92374]
#  [162.94171]
#  [162.82605]
#  [163.6617 ]
#  [161.69041]
#  [161.2598 ]
#  [162.38095]
#  [165.12164]
#  [166.59778]
#  [166.30432]
#  [164.71532]
#  [165.15642]
#  [165.78757]
#  [165.112  ]
#  [163.68042]
#  [162.46194]
#  [162.9484 ]
#  [159.44995]
#  [157.39272]
#  [157.31142]
#  [153.28238]
#  [150.15883]
#  [149.22246]
#  [150.4836 ]
#  [153.28535]
#  [156.34526]
#  [157.75526]
#  [158.86516]
#  [159.5748 ]
#  [161.1947 ]
#  [162.79654]
#  [162.30536]
#  [162.25403]
#  [161.80049]
#  [162.30844]
#  [163.38333]
#  [165.02542]
#  [166.37009]
#  [166.15747]
#  [165.9507 ]
#  [166.62671]
#  [164.33931]
#  [164.20331]
#  [162.80054]
#  [162.22896]
#  [162.89018]
#  [164.30737]
#  [165.12392]
#  [165.26065]
#  [163.81917]
#  [163.48116]
#  [163.84769]
#  [164.67267]
#  [163.54994]
#  [163.01204]
#  [164.4163 ]
#  [165.92894]]
# 3/3 - 1s - 246ms/step - loss: 7.4510e-04 - mean_absolute_error: 0.0210 - mean_absolute_percentage_error: 2.7577 - symmetric_mean_absolute_percentage_error: 2.6098
# loss: 0.0007
# compile_metrics: 0.0210
# SMAPE (manual, rescaled): 1.3565

# %%
plt.figure(figsize=(12, 6))
plt.plot(loaded_scaler.inverse_transform(y_test.reshape(-1, 1)), label="Actual Prices", color="darkorange", alpha=0.6, linewidth=2)
plt.plot(loaded_scaler.inverse_transform(predictions.reshape(-1, 1)), label="Predicted Prices", color="#4285F4", alpha=0.6, linestyle="--", linewidth=2)
plt.title("Stock Price Prediction for Google",fontsize = 26)
plt.xlabel("Time Steps",fontsize = 20)
plt.ylabel("Stock Price (Original Scale)",fontsize = 20)
plt.legend(fontsize = 20)
plt.grid(True)
plt.show()

# %%
